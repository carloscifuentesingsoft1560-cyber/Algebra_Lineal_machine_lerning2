# %%
import sys
print("hola, mundo del algebra lineal")
print(f"Tu version de python es {sys.version}")
# Out:
# hola, mundo del algebra lineal
# Tu version de python es 3.13.7 (tags/v3.13.7:bcee1c3, Aug 14 2025, 14:15:11) [MSC v.1944 64 bit (AMD64)]
